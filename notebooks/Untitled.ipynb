# %%
import pandas as pd

# %%
df=pd.read_csv('detailed_exercise_dataset.csv')

# %%
df
# Out:
#           Exercise Name Type of Activity Type of Equipment   Body Part  \
# 0             Yoga Flow       Stretching       Foam Roller        Core
# 1    Stretching Routine         Strength        Kettlebell  Upper body
# 2             Cable Row          Warm-up   Resistance Band        Core
# 3         Ankle Circles           Cardio           Barbell        Core
# 4             Jump Rope         Mobility       Foam Roller  Lower body
# ..                  ...              ...               ...         ...
# 495       Leg Extension         Mobility        Kettlebell  Lower body
# 496  Stretching Routine       Stretching           Barbell  Upper body
# 497       Bent Over Row         Mobility        Bodyweight  Upper body
# 498          Seated Row          Warm-up           Barbell  Upper body
# 499       Boxing Drills         Mobility           Barbell  Lower body
#
#         Type            Muscle Groups Activated  \
# 0       Hold     Quadriceps, Glutes, Hamstrings
# ...
